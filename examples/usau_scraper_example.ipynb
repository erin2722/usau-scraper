# %% [markdown]
# <a href="https://colab.research.google.com/github/erin2722/usau-scraper/blob/main/examples/usau_scraper_example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # USAU Scraper Examples
# ---
#
# This notebook demonstrates how to use the current usau-scraper python library, with more examples to be added soon!

# %%
# install usau-scraper
# !pip install --upgrade usau-scraper

# %%
# import json for pretty printing
import json

# %% [markdown]
# ## Team Info

# %%
from usau_scraper import getTeamInfo

# You can search for one specific team using schoolName and teamName
print(json.dumps(getTeamInfo(schoolName='Columbia', teamName='Curbside'), indent = 4))

# Or search with even more specific information for a team (encodings will be made easier soon)
print(json.dumps(getTeamInfo(
    schoolName = 'Columbia', 
    teamName = 'Baewatch', 
    genderDivision=2, 
    state='NY', 
    competitionLevel='College', 
    competitionDivision=1, 
    teamDesignation=1), indent=4))

# Search for the first 20 College Womens Teams in New York
print(json.dumps(getTeamInfo(
    genderDivision=2, 
    state='NY', 
    competitionLevel='College'), indent=4))
# Out:
# {
#     "res": "OK",
#     "teams": [
#         {
#             "schoolName": "Columbia",
#             "teamName": "Curbside",
#             "competitionLevel": "College",
#             "genderDivision": "Women",
#             "location": "New York , New York",
#             "twitter": "https://twitter.com/cultimatewomen"
#         }
#     ]
# }
# {
#     "res": "OK",
#     "teams": [
#         {
#             "schoolName": "Columbia-B",
#             "teamName": "Baewatch",
#             "competitionLevel": "College",
#             "genderDivision": "Women",
#             "location": "New York, New York"
#         }
#     ]
# }
# {
#     "res": "OK",
#     "teams": [
#         {
#             "schoolName": "Bard",
#             "teamName": "Big Birds",
#             "competitionLevel": "College",
#             "genderDivision": "Women",
#             "location": "Annandale-on-Hudson, New York"
#         },
#         {
#             "schoolName": "Colgate",
#             "teamName": "The Vibe",
#             "competitionLevel": "College",
#             "genderDivision": "Women",
#             "location": "Hamilton, New York",
#             "facebook": "https://www.facebook.com/Jabbervibe/?fref=ts",
#             "twitter": "https://www.twitter.com/vibeultimate"
#         },
#         {
#             "schoolName": "Columbia",
#             "teamName": "Curbside",
#             "competitionLevel": "College",
#             "genderDivision": "Women",
#             "location": "New York , New York",
#             "twitter": "https://twitter.com/cultimatewomen"
#         },
#         {
#             "schoolName": "Columbia-B",
#             "teamName": "Baewatch",
#             "competitionLevel": "College",
#             "genderDivision": "Women",
#             "location": "New York, New York"
#         },
#         {
#             "schoolName": "Cornell",
#             "teamName": "Wild Roses",
#             "competitionLevel": "College",
#             "genderDivision": "Women",
#             "location": "Ithaca, New York"
#         },
#         {
#             "schoolName": "Cornell-B",
#             "teamName": "Thorny Roses",
#             "competitionLevel": "College",
#             "genderDivision": "Women",
#             "location": "Ithaca, New York",
#             "facebook": "https://m.facebook.com/Cornell-Thorny-Roses-2150085978550757/",
#             "twitter": "https://twitter.com/thornyultimate"
#         },
#         {
#             "schoolName": "Hamilton",
#             "teamName": "Hot Saucers",
#             "competitionLevel": "College",
#             "genderDivision": "Women",
#             "location": "Clinton, New York",
#             "website": "http://hotsaucersultimate.wordpress.com",
#             "twitter": "@hottestsaucers"
#         },
#         {
#             "schoolName": "Ithaca",
#             "teamName": "Kweezy Ultimate",
#             "competitionLevel": "College",
#             "genderDivision": "Women",
#             "location": "Ithaca, New York",
#             "website": "https://www.instagram.com/kweezyultimate/"
#         },
#         {
#             "schoolName": "Marist",
#             "teamName": "FoxU Vixens",
#             "competitionLevel": "College",
#             "genderDivision": "Women",
#             "location": "Poughkeepsie, New York",
#             "facebook": "https://www.facebook.com/maristultimate/",
#             "twitter": "https://twitter.com/maristfoxu"
#         },
#         {
#             "schoolName": "NYU",
#             "teamName": "NYU Purple Reign",
#             "competitionLevel": "College",
#             "genderDivision": "Women",
#             "location": "New York, New York",
#             "coaches": "Olivia Kugiya Head Coach Akina Younge Head Coach"
#         },
#         {
#             "schoolName": "RIT",
#             "teamName": "Yams",
#             "competitionLevel": "College",
#             "genderDivision": "Women",
#             "location": "Rochester, New York",
#             "coaches": "Seana Lindenthaler Head Coach"
#         },
#         {
#             "schoolName": "Rochester",
#             "teamName": "EZ Women",
#             "competitionLevel": "College",
#             "genderDivision": "Women",
#             "location": "Rochester, New York",
#             "coaches": "Chelsea Rybak Head Coach",
#             "website": "https://rochesterezs.wixsite.com/home",
#             "facebook": "https://www.facebook.com/RochesterEZs",
#             "twitter": "https://twitter.com/RochesterEZs"
#         },
#         {
#             "schoolName": "Skidmore",
#             "teamName": "Skidmore College Thoroughbears ",
#             "competitionLevel": "College",
#             "genderDivision": "Women",
#             "location": "Saratoga Springs, New York",
#             "coaches": "Karoline Hart Head Coach"
#         },
#         {
#             "schoolName": "SUNY-Albany",
#             "teamName": "Deception",
#             "competitionLevel": "College",
#             "genderDivision": "Women",
#             "location": "Albany, New York",
#             "website": "http://deceptionultimate.weebly.com/",
#             "facebook": "https://www.facebook.com/pages/Deception-Womens-Ultimate-Frisbee/438416152842101?ref=hl",
#             "twitter": "https://twitter.com/UADeception"
#         },
#         {
#             "schoolName": "SUNY-Binghamton",
#             "teamName": "Big Bear ",
#             "competitionLevel": "College",
#             "genderDivision": "Women",
#             "location": "Binghamton , New York",
#             "coaches": "Danica Vasa Head Coach",
#             "website": "https://bigbearultimate.wordpress.com/",
#             "facebook": "https://www.facebook.com/binghamtonultimate/"
#         },
#         {
#             "schoolName": "SUNY-Buffalo",
#             "teamName": "the Lorax",
#             "competitionLevel": "College",
#             "genderDivision": "Women",
#             "location": "Buffalo, New York"
#         },
#         {
#             "schoolName": "SUNY-Geneseo",
#             "teamName": "Escargot",
#             "competitionLevel": "College",
#             "genderDivision": "Women",
#             "location": "Geneseo, New York",
#             "facebook": "https://www.facebook.com/EscargotUltimate/?fref=ts",
#             "twitter": "https://twitter.com/GeneseoEscargot"
#         },
#         {
#             "schoolName": "SUNY-Stony Brook",
#             "teamName": "Smash",
#             "competitionLevel": "College",
#             "genderDivision": "Women",
#             "location": "Stony Brook, New York",
#             "coaches": "Collin Bartoldus Head Coach",
#             "facebook": "https://www.facebook.com/StonyBrookUltimateFrisbee/",
#             "twitter": "https://twitter.com/PanicDisc"
#         },
#         {
#             "schoolName": "Syracuse",
#             "teamName": "Fox Force Seven",
#             "competitionLevel": "College",
#             "genderDivision": "Women",
#             "location": "Syracuse , New York",
#             "coaches": "Allison Case Head Coach Brian Erwin Head Coach Megan Kirby Head Coach",
#             "facebook": "https://www.facebook.com/FoxForceSeven",
#             "twitter": "https://twitter.com/FoxForceSeven"
#         },
#         {
#             "schoolName": "Vassar",
#             "teamName": "Boxing Nuns",
#             "competitionLevel": "College",
#             "genderDivision": "Women",
#             "location": "Poughkeepsie, New York",
#             "coaches": "Luisa Maria Neves Head Coach"
#         }
#     ]
# }

# %% [markdown]
# ## Team Schedule

# %%
from usau_scraper import getTeamSchedule

# Search for a team's schedule for the current season
print(json.dumps(getTeamSchedule(schoolName='Columbia', teamName='Curbside'), indent = 4))
# Out:
# {
#     "res": "OK",
#     "teams": [
#         {
#             "schoolName": "Columbia",
#             "teamName": "Curbside",
#             "competitionLevel": "College",
#             "genderDivision": "Women",
#             "location": "New York , New York",
#             "wins": 6,
#             "losses": 13,
#             "tournaments": {
#                 "Commonwealth Cup Weekend2 2023": {
#                     "games": [
#                         {
#                             "date": "February 25",
#                             "score": "5 - 13",
#                             "opponentCollege": "SUNY-Binghamton ",
#                             "opponentHref": "/teams/events/Eventteam/?TeamId=mDLoZh6S4QtaCSiGBfFbKQTNsZcFXPqqNI6EMjCchOY%3d"
#                         },
#                         {
#                             "date": "February 25",
#                             "score": "1 - 13",
#                             "opponentCollege": "Northeastern",
#                             "opponentHref": "/teams/events/Eventteam/?TeamId=e%2bQORWqo2HjaJPTVKgBdWfvWdi0bkYCaaQLP9OjXX5Q%3d"
#                         },
#                         {
#                             "date": "February 25",
#                             "score": "8 - 10",
#                             "opponentCollege": "Penn State ",
#                             "opponentHref": "/teams/events/Eventteam/?TeamId=1sLnimD0bMlZkaDYI8mYSYvJFiDY4LMoFKLtr1ZfZuk%3d"
#                         },
#                         {
#                             "date": "February 25",
#                             "score": "5 - 11",
#                             "opponentCollege": "Virginia",
#                             "opponentHref": "/teams/events/Eventteam/?TeamId=DiUJ%2bNa220wWA71L3Grai62w7woLbYeiYPGpbdIax7M%3d"
#                         },
#                         {
#                             "date": "February 26",
#                             "score": "5 - 11",
#                             "opponentCollege": "Brown",
#                             "opponentHref": "/teams/events/Eventteam/?TeamId=y9YMAOuLuV5v6v2VCWa2xWG2bS372YT9jNQ1SDYhFYU%3d"
#                         },
#                         {
#                             "date": "February 26",
#                             "score": "8 - 12",
#                             "opponentCollege": "Case Western Reserve",
#                             "opponentHref": "/teams/events/Eventteam/?TeamId=hGpGcQPcvQiNf%2frCwNh5l0cZXxHdp7Madjb7HkLXYhE%3d"
#                         },
#                         {
#                             "date": "February 26",
#                             "score": "8 - 11",
#                             "opponentCollege": "Ohio State",
#                             "opponentHref": "/teams/events/Eventteam/?TeamId=Ks9P3bmYwSYT6Iu%2fWAI%2bh5pE91b9GwRtOfp417K7ksM%3d"
#                         },
#                         {
#                             "date": "February 26",
#                             "score": "F - W",
#                             "opponentCollege": "Massachusetts",
#                             "opponentHref": "/teams/events/Eventteam/?TeamId=fvXthIto3VMlY668q5fiTXsu%2bxRxDWU%2f6nymMjBSMhc%3d"
#                         }
#                     ]
#                 },
#                 "No Sleep Till Brooklyn 2023": {
#                     "games": [
#                         {
#                             "date": "March 04",
#                             "score": "7 - 9",
#                             "opponentCollege": "Cornell",
#                             "opponentHref": "/teams/events/Eventteam/?TeamId=swZShzB%2bFK4tsqtqa%2f511SwW9nXxGho7MjxCYzUxwlM%3d"
#                         },
#                         {
#                             "date": "March 04",
#                             "score": "9 - 6",
#                             "opponentCollege": "Rutgers",
#                             "opponentHref": "/teams/events/Eventteam/?TeamId=Cx6jfxJr%2bTJsYl3Z3urhSz4tpQxIcvCualgJhm1k%2b4w%3d"
#                         },
#                         {
#                             "date": "March 04",
#                             "score": "8 - 6",
#                             "opponentCollege": "Bates",
#                             "opponentHref": "/teams/events/Eventteam/?TeamId=qmVAo7N%2ftRZfIFCu881VvxKKXav4UKHaB842B%2bV%2fOD8%3d"
#                         },
#                         {
#                             "date": "March 05",
#                             "score": "6 - 8",
#                             "opponentCollege": "Williams",
#                             "opponentHref": "/teams/events/Eventteam/?TeamId=t1%2bUZ9UKbj6kJdnTioIuZWSnPEnaeyxXCvaufWX7QOQ%3d"
#                         },
#                         {
#                             "date": "March 05",
#                             "score": "8 - 5",
#                             "opponentCollege": "Harvard",
#                             "opponentHref": "/teams/events/Eventteam/?TeamId=Qes6Me2QohbI%2faNOUJQwedpQQwIdMXQLxWGTGRzTie8%3d"
#                         }
#                     ]
#                 },
#                 "Garden State": {
#                     "games": [
#                         {
#                             "date": "March 25",
#                             "score": "7 - 5",
#                             "opponentCollege": "Ithaca",
#                             "opponentHref": "/teams/events/Eventteam/?TeamId=CzlLcEL3JpAbLat%2bM8GyCppKYN0UFXStfCyNMDIvuSM%3d"
#                         },
#                         {
#                             "date": "March 25",
#                             "score": "10 - 6",
#                             "opponentCollege": "Lehigh",
#                             "opponentHref": "/teams/events/Eventteam/?TeamId=QYupZxnIbxsJy%2bhr%2b5DQ2wNQb5f49k0a6A%2fSKzHVAjs%3d"
#                         },
#                         {
#                             "date": "March 25",
#                             "score": "3 - 8",
#                             "opponentCollege": "Haverford/Bryn Mawr",
#                             "opponentHref": "/teams/events/Eventteam/?TeamId=qEt3%2fCqcYBFFQqs8Upn13gaClaKA1mv9fUg9IQEmFnk%3d"
#                         },
#                         {
#                             "date": "March 26",
#                             "score": "13 - 0",
#                             "opponentCollege": "Messiah",
#                             "opponentHref": "/teams/events/Eventteam/?TeamId=59AxEArdHdi9rBdJ9tCWrVWiji4Vtx1yOP0DVF4iVls%3d"
#                         },
#                         {
#                             "date": "March 26",
#                             "score": "2 - 8",
#                             "opponentCollege": "Lehigh",
#                             "opponentHref": "/teams/events/Eventteam/?TeamId=QYupZxnIbxsJy%2bhr%2b5DQ2wNQb5f49k0a6A%2fSKzHVAjs%3d"
#                         },
#                         {
#                             "date": "March 26",
#                             "score": "F - W",
#                             "opponentCollege": "Vermont [B]",
#                             "opponentHref": "/teams/events/Eventteam/?TeamId=nWT2%2fySn130vDkL4CVuK90uXi9yN93csEM1ZKcCGcm8%3d"
#                         }
#                     ]
#                 }
#             }
#         }
#     ]
# }

# %% [markdown]
# ## Team Roster

# %%
from usau_scraper import getTeamRoster

# Search for a team's roster for the current season
print(json.dumps(getTeamRoster(schoolName='Columbia', teamName='Curbside'), indent = 4))
# Out:
# {
#     "res": "OK",
#     "teams": [
#         {
#             "schoolName": "Columbia",
#             "teamName": "Curbside",
#             "competitionLevel": "College",
#             "genderDivision": "Women",
#             "location": "New York , New York",
#             "roster": [
#                 {
#                     "no": "0",
#                     "name": "Lily Bresee",
#                     "pronouns": "",
#                     "position": "",
#                     "year": "",
#                     "height": ""
#                 },
#                 {
#                     "no": "0",
#                     "name": "Maia Donald",
#                     "pronouns": "S/T",
#                     "position": "",
#                     "year": "",
#                     "height": ""
#                 },
#                 {
#                     "no": "0",
#                     "name": "Ishika Kaushal",
#                     "pronouns": "",
#                     "position": "",
#                     "year": "",
#                     "height": ""
#                 },
#                 {
#                     "no": "0",
#                     "name": "Alexandra Koletsos",
#                     "pronouns": "S",
#                     "position": "",
#                     "year": "",
#                     "height": ""
#                 },
#                 {
#                     "no": "0",
#                     "name": "Tien Lardner",
#                     "pronouns": "",
#                     "position": "",
#                     "year": "",
#                     "height": ""
#                 },
#                 {
#                     "no": "0",
#                     "name": "Erin McNulty",
#                     "pronouns": "",
#                     "position": "",
#                     "year": "",
#                     "height": ""
#                 },
#                 {
#                     "no": "0",
#                     "name": "Leanne Palisoc",
#                     "pronouns": "",
#                     "position": "",
#                     "year": "",
#                     "height": ""
#                 },
#                 {
#                     "no": "0",
#                     "name": "Sareena Parikh",
#                     "pronouns": "",
#                     "position": "",
#                     "year": "",
#                     "height": ""
#                 },
#                 {
#                     "no": "0",
#                     "name": "Isabelle Puhl",
#                     "pronouns": "",
#                     "position": "",
#                     "year": "",
#                     "height": ""
#                 },
#                 {
#                     "no": "0",
#                     "name": "Talia Sachs",
#                     "pronouns": "",
#                     "position": "",
#                     "year": "",
#                     "height": ""
#                 },
#                 {
#                     "no": "0",
#                     "name": "Andie Tappenden",
#                     "pronouns": "S",
#                     "position": "",
#                     "year": "",
#                     "height": ""
#                 },
#                 {
#                     "no": "0",
#                     "name": "Annabelle Wechsler",
#                     "pronouns": "S",
#                     "position": "",
#                     "year": "",
#                     "height": ""
#                 },
#                 {
#                     "no": "0",
#                     "name": "Alicia Yang",
#                     "pronouns": "",
#                     "position": "",
#                     "year": "",
#                     "height": ""
#                 },
#                 {
#                     "no": "4",
#                     "name": "Marisol Martinez",
#                     "pronouns": "",
#                     "position": "",
#                     "year": "",
#                     "height": ""
#                 },
#                 {
#                     "no": "7",
#                     "name": "Aya Lahlou",
#                     "pronouns": "S",
#                     "position": "",
#                     "year": "College (GR)",
#                     "height": "5'5\""
#                 },
#                 {
#                     "no": "11",
#                     "name": "Nina Haskins",
#                     "pronouns": "",
#                     "position": "",
#                     "year": "",
#                     "height": ""
#                 },
#                 {
#                     "no": "17",
#                     "name": "Ji Yoon Sim",
#                     "pronouns": "S",
#                     "position": "",
#                     "year": "",
#                     "height": "5'3\""
#                 },
#                 {
#                     "no": "24",
#                     "name": "Eastelle Ding",
#                     "pronouns": "S",
#                     "position": "",
#                     "year": "",
#                     "height": ""
#                 }
#             ]
#         }
#     ]
# }
